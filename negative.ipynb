# %%
import numpy as np
import pandas as pd

# %%
conflicts = pd.read_csv("african_conflicts.csv")
conflicts.head()
# Out:
#    Event ID  Event Date          Source Name  \
# 0  33898818  2019-01-01     Military (Benin)
# 1  33898895  2019-01-01        United States
# 2  33898986  2019-01-01            Al-Akhbar
# 3  33899054  2019-01-01     Muhammadu Buhari
# 4  33899021  2019-01-01  State Media (Sudan)
#
#                                       Source Sectors Source Country  \
# 0                                Government,Military          Benin
# 1                                                NaN  United States
# 2  Social,Executive,Government,Print News,News,Me...          Egypt
# 3  Executive Office,(National) Major Party,Partie...        Nigeria
# 4  Executive,Government,Information / Communicati...          Sudan
#
#                           Event_Text  CAMEO Code  Intensity  \
# 0  Mobilize or increase armed forces         154       -7.2
# 1                  Praise or endorse          51        3.4
# 2            Make optimistic comment          13        0.4
# ...

# %%
conflict_occ = conflicts.groupby(["Target Country"]).count()["Intensity"]
max_occ = conflict_occ.max()
normalized = conflict_occ/max_occ

# %%
normalized
# Out:
# Target Country
# Algeria                         0.242324
# Angola                          0.089150
# Benin                           0.023439
# Botswana                        0.023309
# Burkina Faso                    0.084263
# Burundi                         0.017060
# Cameroon                        0.073149
# Central African Republic        0.035915
# Chad                            0.048694
# Comoros                         0.005125
# Cote d'Ivoire                   0.184073
# Democratic Republic of Congo    0.121216
# Djibouti                        0.007633
# Egypt                           0.438614
# Equatorial Guinea               0.008303
# Eritrea                         0.047072
# Ethiopia                        0.193673
# Gabon                           0.021385
# Gambia                          0.041926
# Ghana                           0.082360
# Guinea                          0.043894
# Guinea-Bissau                   0.007633
# ...
